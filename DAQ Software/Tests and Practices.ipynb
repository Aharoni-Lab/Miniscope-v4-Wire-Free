# %%
import tkinter as tk
import cv2

# %%
main = tk.Tk()
main.title('Wire-free V4 MiniScope: Data Acquisition Software')
close = tk.Button(main, text='Close', width=25, command=main.destroy)
close.grid(row = 3, column  = 1)
tk.Label(main, text='Drive Name').grid(row = 0)
tk.Label(main, text='Starting Sector').grid(row = 1)
e1 = tk.Entry(main)
e2 = tk.Entry(main)
e1.grid(row = 0, column = 1)
e2.grid(row = 1, column = 1)
main.mainloop()

# %%
class App:

    def __init__(self, master):

        frame = tk.Frame(master)
        frame.pack()

        self.button = tk.Button(frame, text = "Close", fg = "red", command=root.destroy)
        self.button.pack(side = "right")

        self.hi_there = tk.Button(frame, text = "Hello", command = self.say_hi)
        self.hi_there.pack(side = "left")

    def say_hi(self):
        print("hi there, everyone!")

root = tk.Tk()

app = App(root)

root.mainloop()
# Out:
# hi there, everyone!
# hi there, everyone!

# %%
# Check Write Key/MiniScope Setting

# variables that you can adjust
driveName = r"\\.\PhysicalDrive1"  # Change this to the correct drive
sectorSize = 512    # The number of bytes in a sector (two hexidecimal numbers is 8 bits, or a byte)
startingSector = 2097152


f = open(driveName, "rb+")  # Open drive

f.seek(startingSector * sectorSize - sectorSize)  # Move to correct sector
rawBytes = f.read(sectorSize)
print(rawBytes)

f.seek(startingSector * sectorSize - sectorSize)  # Move to correct sector
f.write(b'\x17\xba|\r\x17\xba|\r\x17\xba|\r\x17\xba|\r')

f.seek(startingSector * sectorSize - sectorSize)  # Move to correct sector
testBytes = f.read(sectorSize)
print(testBytes)
# Out:
# b'\x17\xba|\r\x17\xba|\r\x17\xba|\r\x17\xba|\r\x05\x00\x00\x00\x05\x00\x00\x00c\x0
# ...
